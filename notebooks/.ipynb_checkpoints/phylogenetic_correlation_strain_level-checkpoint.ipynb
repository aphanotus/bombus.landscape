# %%
import pandas as pd
from skbio import DistanceMatrix
from skbio.stats.distance import mantel
from qiime2 import Artifact
from qiime2.plugins.taxa.methods import filter_table
from qiime2.plugins.diversity_lib.methods import weighted_unifrac
import rpy2, os
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Calculate correlations between the genus-specific B diversity between samples, and host phylogeny

# %% [markdown]
# ## Setup

# %% [markdown]
# read feature tables, rooted tree

# %%
taxa_6 = Artifact.load('../data/qiime/mt_99_c6.qza').view(pd.DataFrame)
mt_99 = Artifact.load('../data/qiime/mt_99.qza')

rooted_tree_99=Artifact.load('../data/qiime/rooted_tree_99.qza')

# %% [markdown]
# determine taxa found in more than 10% of samples

# %%
#found in 10%
withstrains = set(list((taxa_6 >0).sum()[(taxa_6 >0).sum() > taxa_6.shape[0]*.1].index))
#genus
withstrains = [x for x in withstrains if 'g__' in x]
#shortname
withstrains = list(map(lambda x: x.split('__')[-1], withstrains))
withstrains = set(withstrains)

# %%
len(withstrains)
# Out:
# 28

# %% [markdown]
# calculate weighted unifrac for taxa-specific fractions of the microbiome

# %%
# pull out OTUs
tables = {c: filter_table(mt_99, taxa, include= c, mode='contains') \
for c in withstrains}
# weighted unifrac 
wus = {c: weighted_unifrac(tables[c].filtered_table,
                           phylogeny = rooted_tree_99) for \
      c in tables}
wus = { c: wus[c].distance_matrix.view(DistanceMatrix) for c in wus}
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/389ab3ec-5f0d-4f6b-ae8a-e91fbc24b435/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-u12rkk3x
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/a9d1a44d-da60-4434-93dc-58feded4e1a4/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-sux3xb0f
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/5ec84e04-3253-4503-b35a-52a908e77087/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-8zxtvxzl
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/be534e04-27ee-4a9b-bc10-1436bfabbdfa/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-xa76g22t
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/c33e6af8-5a42-48c2-9e91-fa7dbb63508d/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-ipem9v5k
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/ed0670e3-e7de-4499-8909-4da4f9feef3e/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-hu1pf6p6
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/10f811d5-4531-4e23-9d43-20f528aa85a5/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data
var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-nes3ju80
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/71208138-9fe8-49df-a416-5029718425e8/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-8pofz1ty
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/1371b437-ce31-4062-848f-b845ff752598/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-c5jnaywp
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/1b9e6315-23eb-4e07-886c-68618d70efbd/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-_bau5ndy
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/12130a63-1d5f-439b-aa22-2f4a3f36faf2/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-ctwn9b0g
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/23c3d2b4-d3a3-4999-abdc-9d48e56988b2/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-_x5u34am
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/af5873b1-cc64-4123-be03-05e66084752c/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-csk2ocyc
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/5c4c523f-5f01-4dec-9271-71a45193d96e/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-aj7lspsl
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/251b92b0-1c7c-4e6b-84ab-369dff614066/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-u_jyb5uh
#
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command:
#
# ssu -i /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/d1a8d756-1c32-4dff-ad60-d7cf6cf62eff/data/feature-table.biom -t /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/qiime2/youngm/data/8993fc5c-82ad-44d7-b7fa-84799c880a34/data/tree.nwk -m weighted_unnormalized -o /var/folders/hd/67t7954n4_bd9_fw90jxq_l00000gp/T/q2-LSMatFormat-w9l4kqcx

# %% [markdown]
# read in the host data

# %%
dm_host =pd.read_csv( '../data/dm/dm_host.tsv', index_col=0, sep = '\t')
dm_host = DistanceMatrix(dm_host[dm_host.index], ids = dm_host.index)

# %% [markdown]
# ## test for correlations
#
# pos corr = OTU similarity proportional to host phylogenetic similarity

# %%
mantel_corrs = {c: mantel(wus[c], dm_host, strict=False) for c \
               in wus}
pd.DataFrame.from_dict(mantel_corrs, orient = 'index', 
                      columns = ['corr', 'p', 'n_samples']).sort_values(by='p')
# Out:
#                                                         corr      p  n_samples
# Bifidobacterium                                     0.433609  0.001        449
# Gilliamella                                         0.291820  0.001        612
# Saccharibacter                                      0.121421  0.005        149
# Asaia                                               0.259560  0.006         73
# Pseudomonas                                         0.035748  0.008        421
# Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium  0.132430  0.013        173
# Chloroplast                                         0.107899  0.019        304
# Apibacter                                           0.080329  0.044        257
# Hafnia-Obesumbacterium                              0.079871  0.051        162
# Candidatus_Schmidhempelia                           0.069336  0.095        584
# Spiroplasma                                         0.140529  0.110         71
# Leifsonia                                          -0.081490  0.137         92
# Acinetobacter                                      -0.034839  0.273        409
# Bombiscardovia                                     -0.026492  0.275        355
# Pantoea                                             0.048168  0.286        185
# Fructobacillus                                      0.007226  0.352        336
# Cutibacterium                                      -0.039938  0.416        116
# Stenotrophomonas                                   -0.029415  0.529        181
# Rosenbergiella                                      0.028960  0.543        199
# Ochrobactrum                                       -0.029148  0.549        223
# Escherichia-Shigella                               -0.043208  0.567         64
# Snodgrassella                                      -0.014681  0.620        627
# Massilia                                           -0.029535  0.701        124
# Erwinia                                             0.005842  0.738        368
# Leuconostoc                                         0.010602  0.749        356
# Cellulomonas                                        0.030703  0.759        118
# Lactobacillus                                       0.001492  0.938        333
# Methylobacterium-Methylorubrum                      0.006127  0.938         70

# %% [markdown]
# ## Use R to run mantel tests, stratified by yearly collection sites

# %% [markdown]
# write data

# %%
if not os.path.isdir('../data/table/mantel'):
    os.mkdir('../data/table/mantel')
for c in wus:
    temp = wus[c].to_data_frame().copy()
    temp.columns = ['x' + x for x in temp.columns]
    temp.index = ['x' + x for x in temp.index]
    temp.to_csv('../data/table/mantel/'+c+'.tsv', sep ='\t')

# %% [markdown]
# make index names in the host dm R-safe

# %%
dm_host = dm_host.to_data_frame()
dm_host.columns = ['x' + x for x in dm_host.columns]
dm_host.index = ['x' + x for x in dm_host.index]

# %% [markdown]
# Read in metadata, get site strata

# %%
bombusMeta = pd.read_csv('../data/BombusMetadata.tsv', sep='\t',
                        index_col=0)
strata = bombusMeta['site_year']
strata.index = ['x' + x for x in strata.index]

# %% [markdown]
# Read into R, calculate, write

# %%
# %load_ext rpy2.ipython

# %%
if not os.path.isdir('../data/table/mantel_results'):
    os.mkdir('../data/table/mantel_results')

# %%
# %%R -i dm_host,strata
#
# library(vegan)
#
# for (c in list.files(path = "../data/table/mantel")){
#     dm <- read.table(paste0("../data/table/mantel/", c))
#     res <- mantel(dm, dm_host[rownames(dm), colnames(dm)], strata = strata[rownames(dm)])
#     sink(paste0('../data/table/mantel_results/', c))
#     print(res$statistic)
#     print(res$signif)
#     sink()
# }

# %% [markdown]
# Four significant, after stratification and FDR correction

# %%
pms = pd.concat([pd.read_csv(os.path.join('../data/table/mantel_results', x), sep =' ',
    header = None)[[1]].transpose().rename(index = {1: x.split('.tsv')[0]},
    columns = {0: 'r', 1:'p'}) for x in os.listdir('../data/table/mantel_results') if \
          x.endswith('tsv')])
pms['fdrbh'] = sm.stats.multipletests(pms['p'],
                       method = 'fdr_bh', is_sorted=False,
                       returnsorted=False, alpha=0.1)[1]
pms.sort_values(by ='p')
# Out:
#                                                            r      p     fdrbh
# Saccharibacter                                      0.121421  0.001  0.009333
# Bifidobacterium                                     0.433609  0.001  0.009333
# Gilliamella                                         0.291820  0.001  0.009333
# Asaia                                               0.259559  0.007  0.049000
# Allorhizobium-Neorhizobium-Pararhizobium-Rhizobium  0.132430  0.061  0.264000
# Apibacter                                           0.080329  0.065  0.264000
# Fructobacillus                                      0.007226  0.066  0.264000
# Leuconostoc                                         0.010602  0.084  0.294000
# Spiroplasma                                         0.140529  0.096  0.298667
# Chloroplast                                         0.107898  0.147  0.411600
# Candidatus_Schmidhempelia                           0.069336  0.201  0.511636
# Erwinia                                             0.005842  0.236  0.550667
# Leifsonia                                          -0.081490  0.261  0.562154
# Methylobacterium-Methylorubrum                      0.006127  0.327  0.636533
# Massilia                                           -0.029535  0.341  0.636533
# Pseudomonas                                         0.035748  0.477  0.834750
# Pantoea                                             0.048168  0.578  0.935667
# Hafnia-Obesumbacterium                              0.079871  0.640  0.935667
# Rosenbergiella                                      0.028960  0.671  0.935667
# Lactobacillus                                       0.001492  0.676  0.935667
# Ochrobactrum                                       -0.029148  0.716  0.935667
# Stenotrophomonas                                   -0.029415  0.740  0.935667
# Cutibacterium                                      -0.039938  0.777  0.935667
# Bombiscardovia                                     -0.026492  0.802  0.935667
# Snodgrassella                                      -0.014681  0.839  0.938000
# Acinetobacter                                      -0.034839  0.871  0.938000
# Escherichia-Shigella                               -0.043208  1.000  1.000000
# Cellulomonas                                        0.030703  1.000  1.000000

# %% [markdown]
# # Barplot of OTU reulative abundances

# %% [markdown]
# **calculate cumulative sum of average relative abundances of OTUs**

# %%
tables = {c: tables[c].filtered_table.view(pd.DataFrame) for c in tables}
tables = pd.concat([(tables[x].transpose() /tables[x].sum(axis=1)\
            ).dropna().mean(axis=1).sort_values(ascending=False\
    ).reset_index().drop(columns='index').transpose().rename({0:x}) for \
          x in tables])
tables = tables.sort_values(by = 0, ascending=False).fillna(0)
tables = tables.transpose().cumsum().transpose()
tables = tables.reset_index().reset_index()

# %%
sns.set(style = 'white', palette = 'dark')
fig, ax = plt.subplots(figsize = (9, 5))
for i in np.arange(53, -1, -1):
    plt.bar(x = tables['level_0'], height = tables[i], 
           linewidth=0.3, alpha = 1, width=.9)
plt.xticks(tables['level_0'], labels = tables['index'], rotation = 90)
plt.xlim(-.5, 27.5)
plt.ylim(0,1)
plt.ylabel('OTU99 relative abundances')
plt.show()
fig.savefig('figs/OTU_barplot.pdf',
               format = 'pdf', transparent = True, bbox_inches='tight')
